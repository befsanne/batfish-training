# %% [markdown]
# # Getting Started

# %% [markdown]
# Pybatfishをインポートする。

# %%
from pybatfish.client.commands import *
from pybatfish.question.question import load_questions, list_questions
from pybatfish.question import bfq

# %% [markdown]
# クエスチョンテンプレートをBatfishからpybatfishへロードする。

# %%
load_questions()
# Out:
# Successfully loaded 38 questions from remote

# %% [markdown]
# ネットワークスナップショットをアップロードする(スナップショット名の後にいくつかのログが表示される)。
# bf_init_snapshot()の引数はZipファイルでもいいらしい。

# %%
NETWORK_NAME = "example_network"
SNAPSHOT_NAME = "example_snapshot"
SNAPSHOT_PATH = "networks/example"

bf_set_network(NETWORK_NAME)
bf_init_snapshot(SNAPSHOT_PATH, name=SNAPSHOT_NAME, overwrite=True)
# Out:
# status: TRYINGTOASSIGN
# .... no task information
# status: CHECKINGSTATUS
# .... no task information
# status: CHECKINGSTATUS
# .... Fri Oct 26 06:51:34 2018 JST Parse configurations 2 / 13
# status: CHECKINGSTATUS
# .... Fri Oct 26 06:51:34 2018 JST Parse configurations 12 / 13
# status: ASSIGNED
# .... Fri Oct 26 06:51:34 2018 JST Convert configurations to vendor-independent format 15 / 15
# status: TERMINATEDNORMALLY
# .... Fri Oct 26 06:51:34 2018 JST Deserializing objects of type 'org.batfish.datamodel.Configuration' from files 15 / 15
# Default snapshot is now set to example_snapshot
# 'example_snapshot'

# %% [markdown]
# ロードしたテンプレートの1つを使って、スナップショットに対してクエスチョンする。
# - ロードしたクエスチョンはbfqインスタンスが保持している。
# - answer()はクエスチョンを実行し、回答をJSON形式で返す。
# - クエスチョンの内容とパラメータについては、Batfishのquestionディレクトリを参照。

# %%
ip_owners_ans = bfq.ipOwners().answer()
# Out:
# status: TRYINGTOASSIGN
# .... no task information
# status: TERMINATEDNORMALLY
# .... Fri Oct 26 06:51:48 2018 JST Begin job

# %% [markdown]
# テーブルとして表示する場合、frame()を使って回答をpandas dataframeとしてラップする。

# %%
ip_owners_ans.frame()
# Out:
#           Node      VRF           Interface           IP  Mask  Active
# 0     as2dist2  default           Loopback0      2.1.3.2    32    True
# 1     as2dist1  default           Loopback0      2.1.3.1    32    True
# 2     as2dept1  default  GigabitEthernet1/0   2.34.201.4    24    True
# 3     as2dept1  default           Loopback0      2.1.1.2    32    True
# 4   as3border2  default  GigabitEthernet1/0      3.0.2.1    24    True
# 5     as3core1  default  GigabitEthernet2/0   90.90.90.1    24    True
# 6     as2core1  default  GigabitEthernet2/0    2.23.11.2    24    True
# 7     as2core1  default  GigabitEthernet3/0    2.23.12.2    24    True
# 8   as1border1  default  GigabitEthernet1/0   10.12.11.1    24    True
# 9   as3border1  default           Loopback0      3.1.1.1    32    True
# 10    as2core1  default  GigabitEthernet0/0    2.12.11.2    24    True
# 11  as3border2  default           Loopback0      3.2.2.2    32    True
# ...

# %% [markdown]
# frame().head()とすると、最初の5行が表示される。

# %%
ip_owners_ans.frame().head()
# Out:
#          Node      VRF           Interface          IP  Mask  Active
# 0    as2dist2  default           Loopback0     2.1.3.2    32    True
# 1    as2dist1  default           Loopback0     2.1.3.1    32    True
# 2    as2dept1  default  GigabitEthernet1/0  2.34.201.4    24    True
# 3    as2dept1  default           Loopback0     2.1.1.2    32    True
# 4  as3border2  default  GigabitEthernet1/0     3.0.2.1    24    True

# %% [markdown]
# as1border1のGi0/0に設定されている全てのプレフィックスを確認する場合、interfacePropertiesクエスチョンを使う。

# %%
iface_ans = bfq.interfaceProperties(nodes='as1border1', interfaces='GigabitEthernet0/0',properties='all-prefixes').answer()
# Out:
# status: UNASSIGNED
# .... no task information
# status: TERMINATEDNORMALLY
# .... Wed Oct 24 10:44:56 2018 UTC Begin job

# %%
iface_ans.frame()
# Out:
#                        Interface
# 0  as1border1:GigabitEthernet0/0
